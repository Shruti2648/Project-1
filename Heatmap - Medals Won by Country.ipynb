# %%
# Import dependencies:

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as st
import gmaps
from config import gkey 
import geopandas as gpd

# Read csv file and store into dataframe:

complete_df = pd.read_csv("Resources/athlete_events.csv")

# %%
# Import country names and geocoordinates and store into a dataframe:

coordinates_df = pd.read_csv("Resources/noc_regions.csv")
coordinates_df
# Out:
#      NOC       region                 notes
# 0    AFG  Afghanistan                   NaN
# 1    AHO      Curacao  Netherlands Antilles
# 2    ALB      Albania                   NaN
# 3    ALG      Algeria                   NaN
# 4    AND      Andorra                   NaN
# ..   ...          ...                   ...
# 225  YEM        Yemen                   NaN
# 226  YMD        Yemen           South Yemen
# 227  YUG       Serbia            Yugoslavia
# 228  ZAM       Zambia                   NaN
# 229  ZIM     Zimbabwe                   NaN
#
# [230 rows x 3 columns]

# %%
# Access built-in Natural Earth data via GeoPandas
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
select_country = world.loc[world['name'].isin(coordinates_df["region"].values)]
select_US  = world.loc[world['name'] == "United States of America"]
select_country = pd.concat([select_country, select_US])

# Get a list (dataframe) of country centroids
centroids = select_country.centroid
centroid_list = pd.concat([select_country.name, centroids], axis=1)

# Export to csv
# centroid_list.to_csv(r'centroid_list.csv', index = False)

# %%
# Import centroid_list again:
coordinates = pd.read_csv("centroid_list.csv")

coordinates_df = pd.merge(coordinates, coordinates_df, on='region', how='inner')

# Drop na:
complete_df = complete_df.dropna(subset=["Medal"])

# Merge dataframes:
complete_df.to_csv(r'complete.csv', index = False)
complete_df = pd.merge(complete_df, coordinates_df, on='NOC' , how='inner')
complete_df
# Out:
#            ID                              Name Sex   Age  Height  Weight  \
# 0           4              Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 1        2347  Georg Albert Christian Albertsen   M  30.0     NaN     NaN
# 2        2882           Ejler Arild Emil Allert   M  30.0     NaN     NaN
# 3        3684     Aage Jrgen Christian Andersen   M  22.0     NaN     NaN
# 4        3687             Anders Peter Andersen   M  26.0     NaN    70.0
# ...       ...                               ...  ..   ...     ...     ...
# 31347   95868          Claudia Mara Poll Ahrens   F  27.0   191.0    76.0
# 31348   95868          Claudia Mara Poll Ahrens   F  27.0   191.0    76.0
# 31349   95871                Silvia Poll Ahrens   F  17.0   192.0    75.0
# 31350  104592              Ahmed Salah Houssein   M  31.0   180.0    64.0
# 31351  117747      Zersenay Tadesse Habtesilase   M  22.0   160.0    54.0
#
#                         Team  NOC        Games  Year  Season       City  \
# 0             Denmark/Sweden  DEN  1900 Summer  1900  Summer      Paris
# 1                    Denmark  DEN  1920 Summer  1920  Summer  Antwerpen
# 2      Nykjbings paa Falster  DEN  1912 Summer  1912  Summer  Stockholm
# 3                    Denmark  DEN  1906 Summer  1906  Summer     Athina
# 4                    Denmark  DEN  1908 Summer  1908  Summer     London
# ...                      ...  ...          ...   ...     ...        ...
# 31347             Costa Rica  CRC  2000 Summer  2000  Summer     Sydney
# 31348             Costa Rica  CRC  2000 Summer  2000  Summer     Sydney
# 31349             Costa Rica  CRC  1988 Summer  1988  Summer      Seoul
# 31350               Djibouti  DJI  1988 Summer  1988  Summer      Seoul
# 31351                Eritrea  ERI  2004 Summer  2004  Summer     Athina
#
#             Sport                                          Event   Medal  \
# 0      Tug-Of-War                    Tug-Of-War Men's Tug-Of-War    Gold
# 1      Gymnastics  Gymnastics Men's Team All-Around, Free System    Gold
# 2          Rowing            Rowing Men's Coxed Fours, Inriggers    Gold
# 3        Football                        Football Men's Football    Gold
# 4       Wrestling      Wrestling Men's Middleweight, Greco-Roman  Bronze
# ...           ...                                            ...     ...
# 31347    Swimming          Swimming Women's 200 metres Freestyle  Bronze
# 31348    Swimming          Swimming Women's 400 metres Freestyle  Bronze
# 31349    Swimming          Swimming Women's 200 metres Freestyle  Silver
# 31350   Athletics                       Athletics Men's Marathon  Bronze
# 31351   Athletics                  Athletics Men's 10,000 metres  Bronze
#
#            region  Longitude   Latitude notes
# 0         Denmark   9.876373  56.063934   NaN
# 1         Denmark   9.876373  56.063934   NaN
# 2         Denmark   9.876373  56.063934   NaN
# 3         Denmark   9.876373  56.063934   NaN
# 4         Denmark   9.876373  56.063934   NaN
# ...           ...        ...        ...   ...
# 31347  Costa Rica -84.175423   9.965671   NaN
# 31348  Costa Rica -84.175423   9.965671   NaN
# 31349  Costa Rica -84.175423   9.965671   NaN
# 31350    Djibouti  42.498020  11.773044   NaN
# 31351     Eritrea  38.678187  15.427277   NaN
#
# [31352 rows x 19 columns]

# %%
# Create separate dataframes for summer and winter Olympic games:

medal_df = complete_df[["Medal", "region", "Season", "Latitude", "Longitude"]]
medal_summer = medal_df[medal_df.Season == 'Summer']
medal_winter = medal_df[medal_df.Season == 'Winter']

medal_summer = medal_summer.groupby(['region','Season', 'Latitude', 'Longitude'], as_index=False)['Medal'].count()
medal_winter = medal_winter.groupby(['region','Season', 'Latitude', 'Longitude'], as_index=False)['Medal'].count()

# %%
# Plot heatmap for winter Olympic medals:

figure_layout = {
    'width': '1400px',
    'height': '1000px',
    'border': '1px solid black',
    'padding': '0.5px',
    'margin': '0 auto 0 auto'
}

fig = gmaps.figure(layout=figure_layout,map_type="HYBRID")

locations = medal_winter[["Latitude", "Longitude"]]


medal_count = medal_winter["Medal"].astype(float)
heat_layer = gmaps.heatmap_layer(locations, weights=medal_count,
                                 dissipating=False, max_intensity=5,
                                 point_radius=1)
fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='1000px', margin='0 auto 0 auto', padding='0.5px',…

# %%
# Plot heatmap for summer Olympic medals:

figure_layout = {
    'width': '1400px',
    'height': '1000px',
    'border': '1px solid black',
    'padding': '0.5px',
    'margin': '0 auto 0 auto'
}

fig = gmaps.figure(layout=figure_layout,map_type="HYBRID")

locations = medal_summer[["Latitude", "Longitude"]]


medal_count = medal_summer["Medal"].astype(float)
heat_layer = gmaps.heatmap_layer(locations, weights=medal_count,
                                 dissipating=False, max_intensity=5,
                                 point_radius=1)
fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='1000px', margin='0 auto 0 auto', padding='0.5px',…

# %%
medal_winter.to_csv(r'medal_winter.csv', index = False)
